# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name='inputs')
    labels = tf.placeholder(tf.int32,[None,None],name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/anisio/Courses/Deep-Learning/env_dl/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:1124: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-12-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6452 0.1995 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6137 0.2000 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5015 0.2003 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5973 0.1927 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4960 0.1929 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5351 0.2008 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5667 0.2123 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5576 0.1995 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4458 0.1973 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4394 0.2026 sec/batch
# Nearest to zero: pasteur, albert, cal, angra, malls, banking, find, ccny,
# Nearest to six: contextual, intermodal, coinages, respect, distributivity, connections, front, duhem,
# Nearest to into: oder, biham, dreyer, transjordan, admiral, burner, fair, charcoal,
# Nearest to may: zapatistas, wil, sophie, vcrs, brisson, microfluidics, dissimilar, proscribe,
# Nearest to while: throbbing, bastarnae, sumeria, hyperbola, plaid, underwater, redemption, equations,
# Nearest to th: or, turbocharger, england, interpretation, virology, reusing, insufficiency, lithuania,
# Nearest to b: globally, bruno, consciously, hailie, hominoid, royce, hailing, masoretic,
# Nearest to i: mccay, stalwarts, supremely, punished, saccharomyces, spalding, nonresident, cation,
# Nearest to dr: unaccustomed, korah, malady, tsunami, atrium, questions, barebones, brevity,
# Nearest to bill: transformations, sutton, ouija, unspecified, raged, swains, skies, improvising,
# Nearest to experience: angiosperms, ora, barbecue, bitnet, tanker, agents, initiated, subjugated,
# Nearest to mainly: avail, jorkens, countryside, atrial, establishes, wrecks, undergarments, drilling,
# Nearest to running: concerning, beefheart, ehud, phoebe, mazzola, ql, skates, xxviii,
# Nearest to police: digested, galatians, independence, trna, donati, carnivores, not, near,
# Nearest to report: bert, assessed, premiums, saurischia, bering, fata, aj, resettle,
# Nearest to joseph: flares, huntress, daughters, ferns, profuse, pardons, sachsen, umi,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4696 0.2041 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3827 0.2033 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3417 0.1713 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2493 0.1669 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1811 0.1591 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1548 0.1583 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0835 0.1591 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0658 0.1587 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9866 0.1587 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9795 0.1587 sec/batch
# Nearest to zero: albert, find, pasteur, cal, banking, angra, malls, ccny,
# Nearest to six: front, respect, preparation, contextual, europe, coinages, intermodal, nile,
# Nearest to into: oder, biham, admiral, fair, regularly, involving, charcoal, whatever,
# Nearest to may: sophie, brisson, inherited, york, wil, dissimilar, interpretation, analysis,
# Nearest to while: nations, equations, salvation, namely, bodies, sumeria, redemption, underwater,
# Nearest to th: or, england, interpretation, held, turbocharger, provide, eritrea, entire,
# Nearest to b: globally, consciously, bruno, royce, check, provisional, hailie, ef,
# Nearest to i: mccay, stalwarts, punished, cryogenic, supremely, spalding, scheduling, saccharomyces,
# Nearest to dr: unaccustomed, questions, atrium, korah, ellen, scheduling, responsible, tsunami,
# Nearest to bill: transformations, sutton, raged, unspecified, ouija, destroyed, unbiased, skies,
# Nearest to experience: agents, company, tanker, initiated, angiosperms, barbecue, ora, bitnet,
# Nearest to mainly: avail, establishes, newfoundland, atrial, presented, dirty, jorkens, south,
# Nearest to running: concerning, beefheart, ql, abstinence, phoebe, reacting, encourage, surviving,
# Nearest to police: digested, independence, near, not, honor, carnivores, galatians, hears,
# Nearest to report: bert, assessed, aj, equations, premiums, saurischia, bering, fata,
# Nearest to joseph: flares, daughters, generally, huntress, disqualified, ferns, olympic, weather,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9130 0.1615 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9047 0.1588 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8756 0.1596 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8669 0.1589 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8068 0.1581 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8290 0.1594 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7874 0.1590 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7773 0.1588 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7956 0.1596 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7913 0.1602 sec/batch
# Nearest to zero: albert, banking, pasteur, cal, malls, angra, find, jr,
# Nearest to six: preparation, contextual, nile, distributivity, basin, front, coinages, intermodal,
# Nearest to into: oder, admiral, biham, stained, charcoal, burner, involving, fair,
# Nearest to may: dissimilar, inherited, sophie, interpretation, brisson, wil, sequential, incorrect,
# Nearest to while: equations, redemption, nations, sumeria, salvation, hyperbola, plaid, bodies,
# Nearest to th: eritrea, england, or, turbocharger, interpretation, entire, provisional, anhalt,
# Nearest to b: globally, consciously, bruno, provisional, royce, hailie, anna, ef,
# Nearest to i: punished, mccay, supremely, stalwarts, fulfil, saccharomyces, spalding, cryogenic,
# Nearest to dr: unaccustomed, ellen, questions, korah, ethnicity, brevity, atrium, responsible,
# Nearest to bill: transformations, unspecified, destroyed, sutton, raged, ouija, improvising, skies,
# Nearest to experience: tanker, company, agents, barbecue, angiosperms, unspecified, initiated, rollout,
# Nearest to mainly: establishes, avail, countryside, drilling, warmed, manpower, dirty, south,
# Nearest to running: concerning, beefheart, phoebe, armaments, ql, abstinence, hydrolysis, skates,
# Nearest to police: digested, independence, near, honor, galatians, survivors, trna, hears,
# Nearest to report: bert, assessed, aj, equations, premiums, fata, bering, saurischia,
# Nearest to joseph: flares, olympic, daughters, ferns, weather, generally, huntress, individualistic,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7747 0.1693 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7246 0.1809 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7121 0.1645 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7234 0.1663 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7256 0.1658 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7269 0.1673 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7198 0.1632 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7271 0.1631 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7070 0.1620 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6755 0.1593 sec/batch
# Nearest to zero: albert, banking, angra, cal, pasteur, jr, one, johann,
# Nearest to six: physicist, nile, distributivity, basin, polymerization, preparation, europe, contextual,
# Nearest to into: oder, biham, stained, admiral, charcoal, burner, involving, transjordan,
# Nearest to may: dissimilar, inherited, snape, sophie, sequential, brisson, interpretation, proscribe,
# Nearest to while: redemption, hyperbola, equations, sumeria, bastarnae, postscript, salvation, plaid,
# Nearest to th: eritrea, england, turbocharger, provisional, lithuania, anhalt, reusing, mayer,
# Nearest to b: globally, anna, skylark, bruno, consciously, royce, hailing, painter,
# Nearest to i: punished, mccay, stalwarts, spalding, nonresident, supremely, mingling, saccharomyces,
# Nearest to dr: unaccustomed, ellen, korah, malady, brevity, ethnicity, waldo, doe,
# Nearest to bill: transformations, raged, destroyed, ouija, sutton, unspecified, improvising, rag,
# Nearest to experience: company, tanker, rollout, unspecified, angiosperms, barbecue, ora, bitnet,
# Nearest to mainly: establishes, countryside, avail, warmed, manpower, atrial, wrecks, south,
# Nearest to running: concerning, beefheart, phoebe, ehud, skates, ql, rectifying, hydrolysis,
# Nearest to police: digested, independence, near, hears, honor, trna, survivors, wheatley,
# Nearest to report: bert, assessed, bering, premiums, aj, fata, resettle, mathison,
# Nearest to joseph: flares, individualistic, daughters, olympic, fpus, gama, commander, disqualified,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6827 0.1607 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6634 0.1594 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5970 0.1595 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6328 0.1592 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6274 0.1597 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6427 0.1595 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6056 0.1157 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5661 0.1596 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5244 0.1679 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4918 0.2110 sec/batch
# Nearest to zero: albert, two, angra, banking, mathematician, nine, pasteur, elliott,
# Nearest to six: chemist, physicist, activist, distributivity, poet, basin, samuel, polymerization,
# Nearest to into: oder, biham, stained, charcoal, dreyer, burner, involving, implantation,
# Nearest to may: dissimilar, snape, inherited, severe, sequential, incorrect, proscribe, trait,
# Nearest to while: redemption, salvation, ssl, hyperbola, postscript, bastarnae, plaid, throbbing,
# Nearest to th: england, eritrea, turbocharger, anhalt, provisional, lithuania, severan, mayer,
# Nearest to b: globally, sculptor, anna, painter, skylark, bruno, actress, johann,
# Nearest to i: punished, mccay, stalwarts, spalding, supremely, nonresident, billionaire, mingling,
# Nearest to dr: unaccustomed, ellen, korah, brevity, waldo, malady, doe, ethnicity,
# Nearest to bill: raged, transformations, destroyed, sutton, ouija, unspecified, swains, rag,
# Nearest to experience: ora, company, unspecified, angiosperms, rollout, bitnet, octane, cmos,
# Nearest to mainly: countryside, establishes, avail, warmed, atrial, south, wrecks, manpower,
# Nearest to running: beefheart, concerning, ehud, phoebe, skates, nkvd, ql, rectifying,
# Nearest to police: digested, independence, near, wheatley, honor, trna, donati, looksmart,
# Nearest to report: bert, assessed, mathison, aj, premiums, bering, fata, resettle,
# Nearest to joseph: daughters, olympic, individualistic, fpus, flares, commander, gama, maoist,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4782 0.1734 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4838 0.1576 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4998 0.1589 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5399 0.1589 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4900 0.1589 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4819 0.1594 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4812 0.1590 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4075 0.1592 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4406 0.1609 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4115 0.1586 sec/batch
# Nearest to zero: two, banking, km, four, pasteur, angra, nine, five,
# Nearest to six: basin, rate, polymerization, distributivity, hawai, bordered, closes, coinages,
# Nearest to into: oder, biham, stained, charcoal, implantation, mindedness, burner, dreyer,
# Nearest to may: dissimilar, snape, incorrect, inherited, severe, sequential, vcrs, trait,
# Nearest to while: hyperbola, ssl, plaid, salvation, redemption, boilers, bastarnae, manages,
# Nearest to th: england, eritrea, turbocharger, anhalt, lithuania, tub, mayer, presumptive,
# Nearest to b: globally, royce, bruno, anna, sculptor, hailing, skylark, rb,
# Nearest to i: supremely, punished, stalwarts, nonresident, spalding, mccay, billionaire, dimaggio,
# Nearest to dr: unaccustomed, ellen, korah, waldo, doe, malady, brevity, pitcher,
# Nearest to bill: raged, sutton, ouija, destroyed, transformations, swains, unspecified, rag,
# Nearest to experience: unspecified, ora, rollout, liable, octane, penis, angiosperms, company,
# Nearest to mainly: countryside, establishes, avail, warmed, south, wrecks, atrial, ship,
# Nearest to running: beefheart, ehud, concerning, nkvd, phoebe, skates, metaplot, ql,
# Nearest to police: independence, digested, wheatley, summons, survivors, honor, near, territory,
# Nearest to report: bert, assessed, mathison, fata, aj, slaughters, premiums, groin,
# Nearest to joseph: daughters, flares, gama, fpus, olympic, individualistic, alteration, commander,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4508 0.1612 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4131 0.1590 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4133 0.1590 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3903 0.1594 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4215 0.1590 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4262 0.1587 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3718 0.1591 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3748 0.1592 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4244 0.1587 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3629 0.1608 sec/batch
# Nearest to zero: two, four, one, five, nine, seven, wallis, km,
# Nearest to six: rate, basin, four, polymerization, two, distributivity, hawai, one,
# Nearest to into: charcoal, stained, oder, biham, macfarquhar, mindedness, involving, implantation,
# Nearest to may: dissimilar, severe, vcrs, inherited, snape, proscribe, incorrect, cobra,
# Nearest to while: boilers, hyperbola, ssl, plaid, redemption, salvation, habitus, underwater,
# Nearest to th: england, eritrea, anhalt, turbocharger, mayer, broch, lithuania, severan,
# Nearest to b: globally, royce, rb, anna, ef, sculptor, bruno, painter,
# Nearest to i: punished, supremely, stalwarts, nonresident, mccay, spalding, my, dimaggio,
# Nearest to dr: unaccustomed, ellen, korah, waldo, doe, malady, pitcher, brevity,
# Nearest to bill: raged, sutton, ouija, transformations, destroyed, rag, swains, unspecified,
# Nearest to experience: liable, rollout, ora, unspecified, annul, angiosperms, octane, company,
# Nearest to mainly: countryside, establishes, avail, warmed, south, wrecks, xdsl, mawson,
# Nearest to running: beefheart, ehud, metaplot, nkvd, skates, phoebe, mazzola, jagiellon,
# Nearest to police: independence, digested, wheatley, trna, summons, engagements, looksmart, territory,
# Nearest to report: bert, assessed, mathison, fata, resettle, aj, slaughters, premiums,
# Nearest to joseph: daughters, gama, fpus, commander, individualistic, voigt, flares, olympic,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.4072 0.1611 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3692 0.1582 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3560 0.1592 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3653 0.1588 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3604 0.1823 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3677 0.1583 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4258 0.1565 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3720 0.1564 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3286 0.1566 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3520 0.1565 sec/batch
# Nearest to zero: two, four, one, nine, five, seven, km, eight,
# Nearest to six: rate, two, four, basin, distributivity, one, eight, seven,
# Nearest to into: charcoal, oder, biham, stained, lied, whatever, involving, mindedness,
# Nearest to may: dissimilar, incorrect, proscribe, vcrs, snape, admiralty, severe, trait,
# Nearest to while: boilers, habitus, redemption, hyperbola, salvation, ssl, plaid, usages,
# Nearest to th: england, anhalt, eritrea, turbocharger, mayer, entire, lithuania, lunisolar,
# Nearest to b: globally, royce, rb, sculptor, ef, bruno, painter, anna,
# Nearest to i: supremely, nonresident, my, punished, stalwarts, mccay, billionaire, dimaggio,
# Nearest to dr: unaccustomed, waldo, ellen, korah, pitcher, brevity, malady, doe,
# Nearest to bill: raged, ouija, sutton, transformations, unspecified, destroyed, rag, boasting,
# Nearest to experience: liable, annul, ora, rollout, taff, company, unspecified, octane,
# Nearest to mainly: countryside, establishes, avail, warmed, south, wrecks, undergarments, xdsl,
# Nearest to running: beefheart, skates, ehud, metaplot, nkvd, phoebe, jagiellon, pulls,
# Nearest to police: independence, digested, honor, not, orangutans, bundys, summons, stormont,
# Nearest to report: bert, assessed, mathison, fata, slaughters, resettle, groin, aj,
# Nearest to joseph: daughters, gama, fpus, voigt, alteration, flares, commander, individualistic,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3674 0.1588 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2985 0.1578 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3891 0.1567 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3848 0.1566 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3904 0.1561 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2845 0.1563 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3161 0.1549 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3375 0.1561 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2229 0.1561 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2901 0.1558 sec/batch
# Nearest to zero: two, four, five, one, nine, eight, seven, rate,
# Nearest to six: two, eight, rate, one, four, seven, five, distributivity,
# Nearest to into: charcoal, oder, biham, stained, macfarquhar, implantation, boudinot, transjordan,
# Nearest to may: dissimilar, proscribe, trait, admiralty, vcrs, microfluidics, incorrect, estimators,
# Nearest to while: boilers, redemption, habitus, manages, hyperbola, stylized, salvation, ssl,
# Nearest to th: england, anhalt, eritrea, lunisolar, lithuania, turbocharger, entire, mayer,
# Nearest to b: astronomer, sculptor, italian, royce, globally, painter, bruno, rb,
# Nearest to i: my, supremely, nonresident, mccay, punished, furthered, stalwarts, billionaire,
# Nearest to dr: ellen, waldo, unaccustomed, korah, misfits, doe, jas, lindsay,
# Nearest to bill: sutton, raged, ouija, transformations, unspecified, rectal, january, becker,
# Nearest to experience: liable, company, rollout, octane, annul, taff, unspecified, ora,
# Nearest to mainly: countryside, establishes, avail, enclaves, xdsl, caltrans, tai, warmed,
# Nearest to running: beefheart, metaplot, ehud, skates, nkvd, brabham, interdisciplinarity, fetch,
# Nearest to police: independence, honor, orangutans, bundys, wheatley, summons, digested, stormont,
# Nearest to report: bert, assessed, mathison, fata, groin, premiums, slaughters, resettle,
# Nearest to joseph: daughters, fpus, gama, alteration, commander, voigt, commentary, sterne,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3135 0.1581 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3017 0.1569 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3410 0.0718 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2424 0.1562 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2167 0.1564 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2022 0.1575 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2115 0.1562 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2160 0.1557 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1961 0.1561 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1812 0.1554 sec/batch
# Nearest to zero: two, one, four, five, nine, seven, eight, three,
# Nearest to six: two, rate, one, four, eight, seven, distributivity, three,
# Nearest to into: charcoal, biham, stained, oder, macfarquhar, whatever, implantation, chromaticism,
# Nearest to may: proscribe, dissimilar, trait, incorrect, microfluidics, admiralty, cough, severe,
# Nearest to while: habitus, manages, boilers, redemption, bastarnae, willers, underwater, plaid,
# Nearest to th: anhalt, england, eritrea, lunisolar, entire, turbocharger, lithuania, severan,
# Nearest to b: astronomer, royce, painter, italian, globally, bruno, johann, sculptor,
# Nearest to i: my, supremely, nonresident, billionaire, mccay, stalwarts, furthered, punished,
# Nearest to dr: ellen, waldo, unaccustomed, jas, doe, misfits, malady, korah,
# Nearest to bill: ouija, sutton, raged, transformations, unspecified, rectal, libera, january,
# Nearest to experience: liable, company, annul, unspecified, bitnet, rollout, ora, taff,
# Nearest to mainly: countryside, establishes, caltrans, avail, xdsl, warmed, tai, enclaves,
# Nearest to running: beefheart, ehud, metaplot, fetch, skates, interdisciplinarity, mazzola, brabham,
# Nearest to police: independence, orangutans, digested, bundys, honor, survivors, stormont, nuttall,
# Nearest to report: bert, assessed, mathison, fata, groin, premiums, aj, slaughters,
# Nearest to joseph: gama, daughters, nchhausen, astronomer, theorie, commander, drowned, fpus,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2332 0.1590 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2449 0.1557 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2305 0.1568 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1487 0.1565 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1609 0.1572 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1968 0.1562 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1442 0.1555 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1695 0.1558 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2169 0.1560 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1825 0.1565 sec/batch
# Nearest to zero: two, four, one, five, seven, nine, eight, three,
# Nearest to six: two, four, rate, one, seven, eight, zero, five,
# Nearest to into: charcoal, biham, macfarquhar, stained, implantation, oder, the, asphalt,
# Nearest to may: dissimilar, cough, proscribe, microfluidics, vcrs, incorrect, trait, breeders,
# Nearest to while: hyperbola, boilers, habitus, manages, plaid, ssl, sterol, willers,
# Nearest to th: england, anhalt, lunisolar, eritrea, entire, turbocharger, tallinn, vast,
# Nearest to b: globally, royce, ef, invertible, astronomer, keywork, bruno, italian,
# Nearest to i: my, supremely, nonresident, dimaggio, stalwarts, punished, mccay, timothy,
# Nearest to dr: ellen, waldo, unaccustomed, doe, korah, lindsay, malady, jas,
# Nearest to bill: ouija, sutton, raged, transformations, unspecified, mccarthy, rectal, boasting,
# Nearest to experience: liable, company, rollout, annul, unspecified, ourselves, repudiation, taff,
# Nearest to mainly: countryside, caltrans, establishes, xdsl, tai, radiocarbon, avail, imc,
# Nearest to running: beefheart, fetch, metaplot, interdisciplinarity, skates, ehud, brabham, rotational,
# Nearest to police: independence, orangutans, stormont, nuttall, engagements, bundys, looksmart, survivors,
# Nearest to report: bert, assessed, mathison, fata, castro, aj, groin, corollaries,
# Nearest to joseph: pantheism, theorie, flares, huntress, nchhausen, gama, daughters, fpus,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.2016 0.1575 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2485 0.1566 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1959 0.1567 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1507 0.1565 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1842 0.1566 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1576 0.1568 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2162 0.1569 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1416 0.1563 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1140 0.1569 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1573 0.1557 sec/batch
# Nearest to zero: two, four, one, nine, five, seven, eight, three,
# Nearest to six: two, four, rate, one, eight, seven, three, zero,
# Nearest to into: charcoal, macfarquhar, biham, stained, the, whatever, analogues, implantation,
# Nearest to may: dissimilar, proscribe, microfluidics, cough, admiralty, breeders, kompiler, tentacles,
# Nearest to while: replayed, manages, hyperbola, plaid, displace, recite, headmaster, skating,
# Nearest to th: lunisolar, england, anhalt, entire, eritrea, turbocharger, tallinn, mayer,
# Nearest to b: astronomer, royce, globally, ef, painter, italian, invertible, bruno,
# Nearest to i: my, supremely, timothy, furthered, dimaggio, stalwarts, nonresident, billionaire,
# Nearest to dr: ellen, unaccustomed, waldo, responsible, doe, jas, malady, lindsay,
# Nearest to bill: ouija, sutton, raged, transformations, unspecified, boasting, serious, mccarthy,
# Nearest to experience: liable, company, rollout, ourselves, repudiation, annul, taff, ora,
# Nearest to mainly: countryside, establishes, caltrans, radiocarbon, enclaves, avail, xdsl, igneous,
# Nearest to running: beefheart, metaplot, fetch, interdisciplinarity, skates, ehud, nkvd, mazzola,
# Nearest to police: independence, orangutans, stormont, bundys, nuttall, looksmart, survivors, accused,
# Nearest to report: bert, assessed, mathison, fata, groin, aj, castro, patenting,
# Nearest to joseph: nchhausen, theorie, erskine, commander, huntress, gama, flares, astronomer,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2011 0.1587 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1637 0.1569 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1701 0.1564 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1768 0.1572 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1368 0.1568 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1331 0.1561 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1747 0.1562 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1191 0.1575 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2231 0.1563 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2073 0.1571 sec/batch
# Nearest to zero: two, four, one, nine, five, eight, seven, three,
# Nearest to six: two, four, one, eight, seven, three, zero, five,
# Nearest to into: charcoal, macfarquhar, biham, admiral, the, stained, calumet, palmas,
# Nearest to may: admiralty, proscribe, microfluidics, dissimilar, breeders, zapatistas, cough, kompiler,
# Nearest to while: headmaster, manages, wonderland, replayed, plaid, delicacy, displace, coleman,
# Nearest to th: lunisolar, england, anhalt, entire, eritrea, rd, tallinn, severan,
# Nearest to b: astronomer, italian, painter, royce, sculptor, bruno, actress, johann,
# Nearest to i: my, supremely, timothy, billionaire, nonresident, dimaggio, stalwarts, furthered,
# Nearest to dr: ellen, waldo, unaccustomed, doe, responsible, lindsay, jas, scientists,
# Nearest to bill: ouija, lonergan, raged, mccarthy, boasting, unspecified, participate, transformations,
# Nearest to experience: company, liable, masterful, repudiation, rollout, ourselves, annul, taff,
# Nearest to mainly: countryside, caltrans, avail, establishes, enclaves, imc, radiocarbon, xdsl,
# Nearest to running: beefheart, fetch, interdisciplinarity, skates, ehud, metaplot, independents, depot,
# Nearest to police: independence, orangutans, stormont, accused, bundys, survivors, trials, nuttall,
# Nearest to report: bert, assessed, mathison, shortfalls, groin, fata, slaughters, whether,
# Nearest to joseph: commander, theorie, huntress, nchhausen, gama, flares, deakin, individualistic,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2227 0.1582 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1399 0.1563 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1457 0.1558 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1307 0.1552 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0612 0.1556 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1508 0.1571 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1688 0.1555 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1405 0.1561 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1956 0.0298 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1377 0.1556 sec/batch
# Nearest to zero: two, four, five, one, nine, eight, seven, three,
# Nearest to six: two, one, four, eight, seven, five, rate, zero,
# Nearest to into: charcoal, the, biham, macfarquhar, stained, asphalt, calumet, chromaticism,
# Nearest to may: microfluidics, dissimilar, cough, kompiler, breeders, proscribe, admiralty, tentacles,
# Nearest to while: replayed, headmaster, delicacy, tenets, displace, manages, salvation, recite,
# Nearest to th: lunisolar, england, entire, anhalt, eritrea, rd, tallinn, africaine,
# Nearest to b: astronomer, royce, italian, painter, globally, ef, stafford, bruno,
# Nearest to i: my, supremely, billionaire, nonresident, die, furthered, outperformed, dimaggio,
# Nearest to dr: responsible, ellen, doe, waldo, unaccustomed, jas, lindsay, scientists,
# Nearest to bill: ouija, lonergan, transformations, unspecified, mccarthy, boasting, raged, sutton,
# Nearest to experience: liable, company, repudiation, ourselves, annul, masterful, outreach, conceptions,
# Nearest to mainly: countryside, avail, caltrans, skanderbeg, radiocarbon, establishes, enclaves, weddell,
# Nearest to running: beefheart, fetch, interdisciplinarity, ehud, metaplot, skates, monopoly, independents,
# Nearest to police: independence, accused, orangutans, stormont, trials, nuttall, bundys, survivors,
# Nearest to report: bert, assessed, mathison, shortfalls, fata, whether, slaughters, groin,
# Nearest to joseph: theorie, commander, nchhausen, huntress, deakin, flares, sterne, gama,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0815 0.1593 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0633 0.1572 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0953 0.1563 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0631 0.1561 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0940 0.1568 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0168 0.1565 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0738 0.1565 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0615 0.1566 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1139 0.1559 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0151 0.1559 sec/batch
# Nearest to zero: two, four, five, one, nine, seven, eight, three,
# Nearest to six: two, four, one, seven, eight, zero, five, three,
# Nearest to into: charcoal, the, macfarquhar, biham, stained, asphalt, oder, calumet,
# Nearest to may: microfluidics, cough, breeders, proscribe, kompiler, dissimilar, admiralty, vcrs,
# Nearest to while: replayed, hyperbola, displace, tenets, headmaster, recite, manages, delicacy,
# Nearest to th: lunisolar, entire, rd, england, tallinn, anhalt, eritrea, turbocharger,
# Nearest to b: astronomer, royce, globally, invertible, ef, commutativity, keywork, stafford,
# Nearest to i: my, supremely, die, nonresident, me, billionaire, dimaggio, timothy,
# Nearest to dr: ellen, responsible, waldo, lindsay, doe, jas, unaccustomed, scientists,
# Nearest to bill: ouija, lonergan, unspecified, transformations, rectal, mccarthy, sutton, boasting,
# Nearest to experience: liable, repudiation, ourselves, company, annul, rollout, outreach, conceptions,
# Nearest to mainly: countryside, avail, caltrans, xdsl, weddell, enclaves, radiocarbon, tai,
# Nearest to running: beefheart, fetch, interdisciplinarity, metaplot, ehud, independents, monopoly, skates,
# Nearest to police: orangutans, independence, accused, stormont, bundys, nuttall, ign, survivors,
# Nearest to report: bert, assessed, mathison, shortfalls, jeffreys, news, besieges, aj,
# Nearest to joseph: commander, theorie, deakin, huntress, flares, nchhausen, sterne, gama,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0236 0.1588 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0372 0.1563 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0093 0.1563 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0514 0.1554 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0546 0.1554 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0587 0.1551 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0596 0.1567 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1177 0.1561 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0569 0.1566 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0569 0.1562 sec/batch
# Nearest to zero: two, four, five, one, nine, three, seven, eight,
# Nearest to six: two, four, one, seven, zero, eight, five, three,
# Nearest to into: charcoal, the, macfarquhar, biham, stained, asphalt, calumet, admiral,
# Nearest to may: microfluidics, admiralty, breeders, dissimilar, vcrs, proscribe, cough, kompiler,
# Nearest to while: displace, hyperbola, tenets, headmaster, replayed, recite, forgiving, equations,
# Nearest to th: lunisolar, rd, entire, england, broch, anhalt, nd, tallinn,
# Nearest to b: astronomer, royce, commutativity, ef, globally, invertible, keywork, stafford,
# Nearest to i: my, supremely, me, die, dimaggio, polynomial, t, billionaire,
# Nearest to dr: ellen, responsible, doe, waldo, scientists, lindsay, jas, unaccustomed,
# Nearest to bill: ouija, lonergan, mccarthy, unspecified, transformations, boasting, rectal, sutton,
# Nearest to experience: liable, company, rollout, outreach, ourselves, repudiation, masterful, protozoa,
# Nearest to mainly: countryside, caltrans, avail, weddell, imc, skanderbeg, radiocarbon, tai,
# Nearest to running: beefheart, fetch, interdisciplinarity, independents, metaplot, ehud, depot, skates,
# Nearest to police: orangutans, independence, stormont, accused, ign, trials, bundys, survivors,
# Nearest to report: bert, assessed, shortfalls, mathison, besieges, news, jeffreys, nemours,
# Nearest to joseph: commander, theorie, deakin, huntress, flares, nchhausen, erskine, sterne,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0517 0.1590 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0735 0.1556 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0905 0.1564 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0624 0.1554 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0644 0.1567 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0668 0.1561 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0651 0.1557 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0283 0.1564 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0684 0.1568 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0756 0.1569 sec/batch
# Nearest to zero: two, four, five, one, nine, seven, three, eight,
# Nearest to six: two, four, one, eight, seven, three, zero, five,
# Nearest to into: charcoal, the, macfarquhar, admiral, biham, stained, calumet, pushing,
# Nearest to may: microfluidics, admiralty, proscribe, dissimilar, imt, cough, breeders, zapatistas,
# Nearest to while: displace, headmaster, recite, coleman, replayed, tenets, hyperbola, forgiving,
# Nearest to th: lunisolar, rd, entire, england, century, anhalt, eredivisie, basingstoke,
# Nearest to b: commutativity, royce, astronomer, globally, ef, stafford, provisional, invertible,
# Nearest to i: my, supremely, die, me, billionaire, nonresident, dimaggio, am,
# Nearest to dr: responsible, ellen, scientists, jas, lindsay, unaccustomed, doe, waldo,
# Nearest to bill: ouija, unspecified, lonergan, transformations, participate, rectal, mccarthy, boasting,
# Nearest to experience: liable, ourselves, repudiation, company, outreach, rollout, annul, masterful,
# Nearest to mainly: countryside, skanderbeg, caltrans, avail, radiocarbon, enclaves, mawson, xdsl,
# Nearest to running: beefheart, fetch, interdisciplinarity, ehud, independents, skates, metaplot, depot,
# Nearest to police: orangutans, independence, accused, survivors, ign, stormont, trials, senex,
# Nearest to report: bert, assessed, shortfalls, mathison, besieges, news, nemours, jeffreys,
# Nearest to joseph: commander, theorie, deakin, flares, huntress, erskine, nchhausen, drowned,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0483 0.1582 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9991 0.1563 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0315 0.1561 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0624 0.1568 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0538 0.1569 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1253 0.1564 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1277 0.1562 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0504 0.1558 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0500 0.1561 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0311 0.1559 sec/batch
# Nearest to zero: two, four, five, one, nine, three, seven, eight,
# Nearest to six: two, four, one, eight, zero, seven, three, five,
# Nearest to into: charcoal, the, macfarquhar, calumet, stained, biham, asphalt, sinuous,
# Nearest to may: microfluidics, admiralty, dissimilar, breeders, salutis, imt, vcrs, cough,
# Nearest to while: displace, headmaster, replayed, coleman, recite, tenets, forgiving, hyperbola,
# Nearest to th: lunisolar, rd, century, entire, england, date, basingstoke, romanorum,
# Nearest to b: commutativity, royce, astronomer, ef, invertible, stafford, globally, keywork,
# Nearest to i: my, supremely, die, billionaire, me, am, t, nonresident,
# Nearest to dr: responsible, ellen, scientists, lindsay, jas, doe, laboratory, malady,
# Nearest to bill: ouija, unspecified, lonergan, mccarthy, rectal, participate, boasting, transformations,
# Nearest to experience: rollout, company, ourselves, liable, repudiation, outreach, masterful, taff,
# Nearest to mainly: countryside, caltrans, skanderbeg, avail, enclaves, wendish, radiocarbon, mawson,
# Nearest to running: beefheart, interdisciplinarity, fetch, ehud, depot, independents, knowable, metaplot,
# Nearest to police: independence, accused, orangutans, survivors, ign, stormont, trials, hears,
# Nearest to report: bert, shortfalls, assessed, mathison, besieges, jeffreys, nemours, aj,
# Nearest to joseph: commander, theorie, deakin, huntress, flares, paraphrasing, nchhausen, sterne,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9966 0.1588 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0470 0.1569 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0237 0.1568 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0296 0.1559 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0789 0.1558 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0477 0.1450 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0306 0.1564 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9953 0.1575 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0158 0.1567 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9459 0.1559 sec/batch
# Nearest to zero: two, five, four, one, eight, nine, seven, three,
# Nearest to six: two, one, four, eight, zero, seven, five, three,
# Nearest to into: charcoal, the, macfarquhar, stained, asphalt, biham, calumet, whatever,
# Nearest to may: microfluidics, cough, breeders, proscribe, dissimilar, tentacles, admiralty, subjectively,
# Nearest to while: replayed, displace, tenets, recite, forgiving, headmaster, technicolor, hyperbola,
# Nearest to th: lunisolar, rd, century, date, eredivisie, england, entire, nd,
# Nearest to b: royce, astronomer, stafford, actress, commutativity, italian, invertible, ef,
# Nearest to i: my, supremely, die, me, billionaire, am, dimaggio, nonresident,
# Nearest to dr: ellen, responsible, jas, lindsay, misfits, scientists, doe, waldo,
# Nearest to bill: ouija, unspecified, lonergan, mccarthy, rectal, transformations, boasting, sutton,
# Nearest to experience: repudiation, ourselves, outreach, liable, company, rollout, dsm, annul,
# Nearest to mainly: countryside, skanderbeg, caltrans, wendish, enclaves, radiocarbon, avail, undergarments,
# Nearest to running: beefheart, interdisciplinarity, fetch, independents, ehud, depot, knowable, monopoly,
# Nearest to police: orangutans, accused, ign, trials, survivors, stormont, independence, wheatley,
# Nearest to report: bert, assessed, shortfalls, besieges, aj, jeffreys, mathison, news,
# Nearest to joseph: commander, deakin, theorie, huntress, flares, erskine, nchhausen, left,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9987 0.1594 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9523 0.1562 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0190 0.1557 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0304 0.1565 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0034 0.1562 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9904 0.1557 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9384 0.1574 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9529 0.1564 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9175 0.1553 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9507 0.1561 sec/batch
# Nearest to zero: two, four, five, one, seven, nine, three, eight,
# Nearest to six: two, four, one, zero, seven, eight, three, five,
# Nearest to into: charcoal, the, calumet, asphalt, macfarquhar, stained, biham, analogues,
# Nearest to may: microfluidics, cough, breeders, canadians, dissimilar, vcrs, tentacles, admiralty,
# Nearest to while: replayed, displace, forgiving, hyperbola, thrown, recite, tenets, coleman,
# Nearest to th: lunisolar, rd, century, entire, date, nd, england, eredivisie,
# Nearest to b: commutativity, invertible, royce, globally, provisional, stafford, astronomer, ef,
# Nearest to i: my, me, supremely, die, am, billionaire, t, dimaggio,
# Nearest to dr: ellen, responsible, lindsay, jas, misfits, scientists, doe, malady,
# Nearest to bill: ouija, unspecified, boasting, sutton, mccarthy, rectal, lonergan, transformations,
# Nearest to experience: repudiation, ourselves, company, outreach, rollout, liable, dsm, staging,
# Nearest to mainly: countryside, wendish, undergarments, caltrans, skanderbeg, radiocarbon, enclaves, xdsl,
# Nearest to running: beefheart, interdisciplinarity, fetch, independents, depot, ehud, metaplot, ql,
# Nearest to police: orangutans, stormont, ign, accused, independence, trials, counternarcotics, senex,
# Nearest to report: bert, shortfalls, assessed, news, mathison, aj, rheumatology, terrorism,
# Nearest to joseph: deakin, commander, theorie, huntress, flares, erskine, nchhausen, paraphrasing,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9940 0.1591 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0039 0.1560 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9258 0.1563 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0027 0.1558 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0526 0.1560 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9568 0.1570 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9953 0.1564 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9849 0.1565 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9835 0.1574 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9920 0.1561 sec/batch
# Nearest to zero: two, four, five, one, nine, three, seven, eight,
# Nearest to six: two, one, four, eight, seven, five, three, zero,
# Nearest to into: charcoal, the, macfarquhar, calumet, stained, biham, chukotka, travelling,
# Nearest to may: microfluidics, cough, admiralty, imt, tentacles, vcrs, breeders, dissimilar,
# Nearest to while: replayed, displace, forgiving, recite, tenets, hyperbola, headmaster, coleman,
# Nearest to th: lunisolar, rd, century, nd, eredivisie, date, england, entire,
# Nearest to b: royce, astronomer, commutativity, stafford, provisional, painter, conti, affan,
# Nearest to i: my, me, supremely, am, die, t, dimaggio, billionaire,
# Nearest to dr: ellen, responsible, doe, lindsay, jas, misfits, malady, laboratory,
# Nearest to bill: unspecified, ouija, rectal, lonergan, boasting, mccarthy, transformations, sutton,
# Nearest to experience: company, ourselves, rollout, repudiation, outreach, properties, staging, hagen,
# Nearest to mainly: countryside, undergarments, wendish, glas, malden, fitter, skanderbeg, radiocarbon,
# Nearest to running: beefheart, interdisciplinarity, fetch, independents, depot, ehud, concerning, knowable,
# Nearest to police: orangutans, ign, stormont, accused, trials, survivors, senex, military,
# Nearest to report: bert, assessed, news, shortfalls, nemours, doi, aj, sapporo,
# Nearest to joseph: commander, deakin, theorie, erskine, flares, nchhausen, huntress, h,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0118 0.1593 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9770 0.1564 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9741 0.1563 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9715 0.1558 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9902 0.1560 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0010 0.1567 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9729 0.1560 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9705 0.1565 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9623 0.1557 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0625 0.1571 sec/batch
# Nearest to zero: two, four, five, one, three, eight, nine, six,
# Nearest to six: two, one, four, eight, three, seven, five, zero,
# Nearest to into: the, charcoal, calumet, macfarquhar, sinuous, pseudopod, pushing, goths,
# Nearest to may: microfluidics, admiralty, cough, imt, salutis, tentacles, canadians, situational,
# Nearest to while: displace, headmaster, tenets, recite, forgiving, hyperbola, replayed, coleman,
# Nearest to th: lunisolar, rd, century, date, nd, entire, eredivisie, england,
# Nearest to b: royce, astronomer, commutativity, stafford, conti, provisional, actress, affan,
# Nearest to i: my, me, am, die, supremely, dimaggio, billionaire, beni,
# Nearest to dr: responsible, ellen, jas, malady, laboratory, ghostly, doe, radiotherapy,
# Nearest to bill: unspecified, ouija, lonergan, rectal, mccarthy, freeh, participate, sutton,
# Nearest to experience: repudiation, ourselves, company, outreach, taff, conceptions, masterful, barbecue,
# Nearest to mainly: countryside, skanderbeg, wendish, glas, fitter, undergarments, radiocarbon, avail,
# Nearest to running: beefheart, interdisciplinarity, fetch, independents, depot, ehud, knowable, subtract,
# Nearest to police: orangutans, ign, accused, military, stormont, independence, nuttall, trials,
# Nearest to report: bert, shortfalls, assessed, aj, news, gush, nemours, doi,
# Nearest to joseph: commander, deakin, theorie, erskine, flares, nchhausen, huntress, reconnaissance,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9605 0.1596 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0886 0.1569 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0462 0.1563 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0314 0.1559 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9626 0.1563 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9307 0.1553 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0057 0.1563 sec/batch
# ...
# Nearest to six: one, two, eight, five, four, three, seven, zero,
# Nearest to into: the, from, and, in, pseudopod, dao, which, called,
# Nearest to may: different, canadians, tentacles, there, these, microfluidics, often, be,
# Nearest to while: as, displace, recite, foreshadowing, previously, mainly, phillies, chickens,
# Nearest to th: rd, century, lunisolar, nd, centuries, date, gregorian, late,
# Nearest to b: commutativity, stafford, affan, astronomer, theologian, keywork, hsu, painter,
# Nearest to i: my, me, you, am, what, myself, go, beni,
# Nearest to dr: jekyll, malady, tokyo, mediated, tetanus, coll, ghostly, auvergne,
# Nearest to bill: unspecified, lonergan, ouija, rectal, boasting, worms, wilcox, herbert,
# Nearest to experience: ourselves, properties, cadet, skills, repudiation, hagen, taff, staging,
# Nearest to mainly: fitter, glas, wendish, outmaneuvered, while, countryside, transistors, foreshadowing,
# Nearest to running: independents, line, interdisciplinarity, parodied, subtract, amulet, fetch, kickoffs,
# Nearest to police: ign, cowardice, crossfire, trials, gaskets, cmyk, mathbb, accused,
# Nearest to report: gush, nemours, updating, rheumatology, assessed, news, terrorist, aj,
# Nearest to joseph: deakin, generally, erskine, reconnaissance, reeves, commander, burali, buddy,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8273 0.1592 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8587 0.1569 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8489 0.1569 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8472 0.1571 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8518 0.1567 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8757 0.1573 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8767 0.1567 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8327 0.1567 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8877 0.1572 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8624 0.1572 sec/batch
# Nearest to zero: two, five, four, one, three, six, seven, eight,
# Nearest to six: one, two, eight, five, four, seven, three, zero,
# Nearest to into: the, from, and, dao, in, pseudopod, which, calumet,
# Nearest to may: different, tentacles, canadians, these, there, moonset, often, edd,
# Nearest to while: as, foreshadowing, displace, recite, mainly, previously, sturm, chickens,
# Nearest to th: rd, century, lunisolar, centuries, date, nd, gregorian, late,
# Nearest to b: commutativity, associativity, stafford, affan, hsu, commutator, keywork, provisional,
# Nearest to i: my, me, you, what, go, am, myself, weren,
# Nearest to dr: jekyll, tokyo, malady, auvergne, coll, tetanus, ghostly, mediated,
# Nearest to bill: unspecified, lonergan, ouija, blocs, rectal, appellant, worms, herbert,
# Nearest to experience: ourselves, properties, repudiation, cadet, skills, taff, hagen, hyperactivity,
# Nearest to mainly: wendish, fitter, glas, outmaneuvered, transistors, countryside, while, indigo,
# Nearest to running: independents, line, interdisciplinarity, parodied, subtract, amulet, knowable, amur,
# Nearest to police: trials, cowardice, crossfire, ign, gaskets, towed, mathbb, officers,
# Nearest to report: nemours, updating, gush, assessed, aj, terrorist, news, ifex,
# Nearest to joseph: deakin, generally, reconnaissance, erskine, reeves, burali, commander, left,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8716 0.1596 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8473 0.1568 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8173 0.1573 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8549 0.1565 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8904 0.1577 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8503 0.1577 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9665 0.1561 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8833 0.1567 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9172 0.1563 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8386 0.1574 sec/batch
# Nearest to zero: two, five, four, one, three, six, seven, eight,
# Nearest to six: one, two, eight, four, five, seven, three, zero,
# Nearest to into: the, from, and, in, calumet, dao, pseudopod, alignment,
# Nearest to may: canadians, tentacles, different, often, harmonising, edd, there, moonset,
# Nearest to while: as, foreshadowing, mainly, recite, displace, front, previously, from,
# Nearest to th: century, rd, lunisolar, date, centuries, nd, late, gregorian,
# Nearest to b: commutativity, affan, stafford, astronomer, associativity, trumpeter, hsu, keywork,
# Nearest to i: my, what, me, go, you, am, myself, t,
# Nearest to dr: jekyll, tokyo, coll, malady, laboratory, auvergne, tetanus, ghostly,
# Nearest to bill: unspecified, lonergan, ouija, wilcox, worms, appellant, midland, herbert,
# Nearest to experience: ourselves, properties, cadet, repudiation, hagen, skills, barbecue, hyperactivity,
# Nearest to mainly: glas, countryside, fitter, wendish, while, outmaneuvered, they, indigo,
# Nearest to running: independents, interdisciplinarity, parodied, line, amulet, amur, subtract, sauer,
# Nearest to police: jackets, gaskets, trials, crossfire, mathbb, ign, cowardice, cmyk,
# Nearest to report: nemours, gush, aj, terrorist, news, updating, assessed, guardian,
# Nearest to joseph: deakin, generally, reeves, reconnaissance, burali, erskine, commander, left,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7789 0.1582 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8725 0.1560 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7930 0.1565 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8682 0.1574 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8544 0.1565 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8586 0.1567 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8606 0.0902 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8201 0.1574 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8501 0.1576 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8201 0.1592 sec/batch
# Nearest to zero: two, five, four, one, three, six, seven, eight,
# Nearest to six: one, two, eight, five, seven, four, three, zero,
# Nearest to into: the, from, and, in, dao, pseudopod, which, calumet,
# Nearest to may: different, canadians, tentacles, moonset, often, aries, edd, harmonising,
# Nearest to while: as, foreshadowing, recite, mainly, previously, from, phillies, chickens,
# Nearest to th: century, rd, centuries, lunisolar, date, late, nd, gregorian,
# Nearest to b: one, commutativity, stafford, astronomer, d, associativity, theologian, cromwellian,
# Nearest to i: my, what, me, myself, you, go, am, beni,
# Nearest to dr: jekyll, tokyo, malady, coll, med, tetanus, laboratory, mediated,
# Nearest to bill: unspecified, lonergan, worms, wilcox, ouija, rectal, blocs, boasting,
# Nearest to experience: cadet, skills, repudiation, ourselves, properties, hagen, hyperactivity, gottfredson,
# Nearest to mainly: wendish, countryside, fitter, while, glas, outmaneuvered, they, transistors,
# Nearest to running: independents, interdisciplinarity, line, parodied, amulet, subtract, kickoffs, monopoly,
# Nearest to police: gaskets, trials, jackets, cowardice, recklessly, ign, crossfire, mathbb,
# Nearest to report: nemours, assessed, news, updating, gush, aj, guardian, terrorist,
# Nearest to joseph: deakin, reeves, generally, reconnaissance, burali, erskine, commander, buddy,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8201 0.1599 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8238 0.1572 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8418 0.1561 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7998 0.1571 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8730 0.1566 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8532 0.1560 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8771 0.1564 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7380 0.1566 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8084 0.1567 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7815 0.1560 sec/batch
# Nearest to zero: two, five, four, one, six, three, seven, eight,
# Nearest to six: one, two, eight, five, four, seven, zero, three,
# Nearest to into: and, the, from, in, pseudopod, dao, which, calumet,
# Nearest to may: canadians, different, often, there, tentacles, moonset, be, aries,
# Nearest to while: as, foreshadowing, from, previously, displace, the, phillies, recite,
# Nearest to th: century, rd, centuries, lunisolar, date, nd, late, brasses,
# Nearest to b: commutativity, associativity, stafford, affan, keywork, some, astronomer, set,
# Nearest to i: my, what, me, you, am, myself, beni, weren,
# Nearest to dr: jekyll, tokyo, malady, tetanus, coll, mediated, diamond, korah,
# Nearest to bill: unspecified, lonergan, ouija, worms, rectal, curses, boasting, wilcox,
# Nearest to experience: cadet, properties, repudiation, ourselves, skills, hagen, hyperactivity, suggestibility,
# Nearest to mainly: wendish, glas, fitter, transistors, countryside, they, foreshadowing, coals,
# Nearest to running: independents, interdisciplinarity, line, parodied, subtract, amulet, kickoffs, average,
# Nearest to police: gaskets, jackets, trials, cmyk, crossfire, cowardice, mathbb, ign,
# Nearest to report: nemours, assessed, gush, updating, aj, terrorist, news, ritz,
# Nearest to joseph: generally, burali, deakin, reeves, erskine, reconnaissance, commander, mentioned,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7653 0.1585 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8270 0.1563 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8361 0.1568 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8294 0.1568 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8379 0.1561 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8982 0.1579 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8420 0.1572 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8047 0.1561 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8328 0.1559 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8396 0.1567 sec/batch
# Nearest to zero: two, five, four, one, three, six, seven, eight,
# Nearest to six: one, two, eight, four, five, seven, three, zero,
# Nearest to into: from, the, and, in, called, pseudopod, dao, which,
# Nearest to may: different, canadians, often, be, there, these, not, tentacles,
# Nearest to while: as, foreshadowing, recite, previously, phillies, displace, mainly, dvorak,
# Nearest to th: rd, century, lunisolar, centuries, date, nd, late, gregorian,
# Nearest to b: commutativity, associativity, stafford, astronomer, affan, keywork, theologian, cantacuzenus,
# Nearest to i: my, you, me, what, myself, go, am, weren,
# Nearest to dr: jekyll, tokyo, malady, tetanus, mediated, laboratory, coll, malintzin,
# Nearest to bill: unspecified, worms, lonergan, ouija, rectal, boasting, hrh, curses,
# Nearest to experience: hyperactivity, cadet, skills, hagen, ourselves, dsm, repudiation, properties,
# Nearest to mainly: glas, fitter, wendish, transistors, foreshadowing, outmaneuvered, while, countryside,
# Nearest to running: independents, line, interdisciplinarity, parodied, subtract, amulet, kickoffs, amur,
# Nearest to police: jackets, gaskets, trials, cmyk, ign, crossfire, cowardice, officers,
# Nearest to report: nemours, assessed, gush, updating, news, terrorist, aj, ifex,
# Nearest to joseph: generally, deakin, burali, reeves, erskine, reconnaissance, commander, buddy,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8511 0.1588 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8602 0.1557 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8323 0.1574 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8441 0.1571 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8835 0.1562 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8209 0.1577 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8467 0.1569 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8466 0.1571 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8144 0.1572 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8019 0.1572 sec/batch
# Nearest to zero: two, five, four, one, three, six, eight, seven,
# Nearest to six: one, two, four, eight, seven, five, three, zero,
# Nearest to into: from, the, and, in, pseudopod, dao, called, which,
# Nearest to may: different, canadians, often, be, soap, not, there, moonset,
# Nearest to while: as, foreshadowing, previously, mainly, recite, was, displace, the,
# Nearest to th: century, rd, centuries, date, lunisolar, late, nd, gregorian,
# Nearest to b: commutativity, associativity, keywork, affan, stafford, ystem, sym, astronomer,
# Nearest to i: my, you, me, what, go, myself, am, t,
# Nearest to dr: jekyll, tokyo, malady, coll, mediated, malintzin, tetanus, laboratory,
# Nearest to bill: unspecified, lonergan, worms, blocs, ouija, rectal, appellant, custody,
# Nearest to experience: cadet, ourselves, hyperactivity, repudiation, dsm, suggestibility, hagen, properties,
# Nearest to mainly: glas, while, fitter, transistors, they, wendish, outmaneuvered, foreshadowing,
# Nearest to running: independents, interdisciplinarity, line, subtract, amulet, parodied, knowable, amur,
# Nearest to police: jackets, trials, gaskets, crossfire, cmyk, ign, cowardice, military,
# Nearest to report: gush, nemours, terrorist, assessed, news, updating, aj, ifex,
# Nearest to joseph: generally, burali, deakin, erskine, reeves, reconnaissance, commander, cursor,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8512 0.1591 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8252 0.1575 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9345 0.1564 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9110 0.1565 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8799 0.1557 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8337 0.1576 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7683 0.1558 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8380 0.1561 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7075 0.1570 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8538 0.1571 sec/batch
# Nearest to zero: two, five, four, one, three, seven, six, eight,
# Nearest to six: one, two, seven, eight, five, four, three, zero,
# Nearest to into: the, from, and, in, dao, pseudopod, called, which,
# Nearest to may: different, canadians, often, be, not, tentacles, there, moonset,
# Nearest to while: as, foreshadowing, previously, mainly, thus, recite, uniformity, chickens,
# Nearest to th: century, rd, lunisolar, date, centuries, late, nd, gregorian,
# Nearest to b: commutativity, astronomer, one, theologian, d, trumpeter, stafford, associativity,
# Nearest to i: my, what, myself, me, you, go, am, t,
# Nearest to dr: jekyll, tokyo, malady, malintzin, diamond, laboratory, med, coll,
# Nearest to bill: unspecified, lonergan, ouija, worms, rectal, blocs, wilcox, cruzeiro,
# Nearest to experience: hyperactivity, ourselves, hagen, gottfredson, cadet, repudiation, suggestibility, taff,
# Nearest to mainly: wendish, while, they, glas, transistors, countryside, fitter, outmaneuvered,
# Nearest to running: independents, interdisciplinarity, parodied, amulet, line, subtract, knowable, commuter,
# Nearest to police: trials, gaskets, jackets, cmyk, military, brochs, ign, crossfire,
# Nearest to report: terrorist, gush, news, nemours, assessed, updating, ifex, ritz,
# Nearest to joseph: burali, deakin, erskine, reeves, generally, reconnaissance, commander, gorham,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8496 0.1596 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8153 0.1567 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
